# %% [markdown]
# # Bienvenidos al Taller de Python
# - Donde aprenderemos inteligencia artificial

# %%
# prompt: realiza un gráfico de líneas donde el eje x tiene valores del 1 al 100 y el eje y tiene el valor de x elevado al cuadrado
import matplotlib.pyplot as plt
# Datos para el gráfico
x = list(range(1, 101))
y = [i**2 for i in x]
# Crear el gráfico
plt.plot(x, y)
# Etiquetas de los ejes
plt.xlabel("x")
plt.ylabel("x^2")
# Título del gráfico
plt.title("Gráfico de x^2")
# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
cars = pd.read_csv("/content/drive/MyDrive/Talleres/Taller 27 02 2025/car_price_prediction.csv")

# %%
cars.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format
cars.drop('ID', axis = 1).describe()
# Out:
#               Price  Prod. year  Cylinders   Airbags
# count     19,237.00   19,237.00  19,237.00 19,237.00
# mean      18,555.93    2,010.91       4.58      6.58
# std      190,581.27        5.67       1.20      4.32
# min            1.00    1,939.00       1.00      0.00
# 25%        5,331.00    2,009.00       4.00      4.00
# 50%       13,172.00    2,012.00       4.00      6.00
# 75%       22,075.00    2,015.00       4.00     12.00
# max   26,307,500.00    2,020.00      16.00     16.00

# %%
cars.duplicated().sum()
# Out:
# 313

# %%
cars.drop_duplicates(inplace = True)

# %%
cars.duplicated().sum()
# Out:
# 0

# %%
print(len(cars['Manufacturer'].unique()))
cars['Manufacturer'].unique()
# Out:
# 65
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'OPEL', 'PORSCHE', 'BMW', 'JEEP', 'VOLKSWAGEN',
#        'AUDI', 'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'ACURA', 'LINCOLN', 'VAZ', 'GAZ',
#        'CITROEN', 'LAND ROVER', 'MINI', 'DODGE', 'CHRYSLER', 'JAGUAR',
#        'ISUZU', 'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC',
#        'PEUGEOT', 'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION',
#        'UAZ', 'MERCURY', 'ZAZ', 'ROVER', 'SEAT', 'LANCIA', 'MOSKVICH',
#        'MASERATI', 'FERRARI', 'SAAB', 'LAMBORGHINI', 'ROLLS-ROYCE',
#        'PONTIAC', 'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
cars.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
for i in [ 'Levy', 'Manufacturer', 'Model', 'Prod. year',
       'Category', 'Leather interior', 'Fuel type', 'Mileage',
       'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
       'Airbags']:
       print(i,':', cars[i].nunique())
# Out:
# Levy : 559
# Manufacturer : 65
# Model : 1590
# Prod. year : 54
# Category : 11
# Leather interior : 2
# Fuel type : 7
# Mileage : 7687
# Cylinders : 13
# Gear box type : 4
# Drive wheels : 3
# Doors : 3
# Wheel : 2
# Color : 16
# Airbags : 17

# %%
cars.drop('ID', axis=1, inplace=False).hist(figsize=(20,12))
plt.show();

# %%
cars['Manufacturer'].value_counts().head(5)
# Out:
# Manufacturer
# HYUNDAI          3729
# TOYOTA           3606
# MERCEDES-BENZ    2043
# FORD             1088
# CHEVROLET        1047
# Name: count, dtype: int64

# %%
import seaborn as sns
top_5_manufacturers = cars['Manufacturer'].value_counts().head(5)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_manufacturers.index, y=top_5_manufacturers.values)
plt.title('Top 5 Car Manufacturers')
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
cars['Manufacturer'].value_counts().sort_values(ascending= False).head(5).sort_values(ascending= True).plot(kind='barh');

# %%
# prompt: utiliza altair para graficar el conteo de registros para cada manufacturer en cars['Manufacturer'].value_counts().sort_values(ascending= False).head(5).sort_values(ascending= True).plot(kind='barh');

import altair as alt
import pandas as pd

# Assuming 'cars' DataFrame is already loaded as in your provided code.
# If not, load it:
# cars = pd.read_csv("/content/drive/MyDrive/Talleres/Taller 27 02 2025/car_price_prediction.csv")

manufacturer_counts = cars['Manufacturer'].value_counts().sort_values(ascending=False).head(5).sort_values(ascending=True)

# Create a DataFrame for Altair
df_manufacturer_counts = pd.DataFrame({'Manufacturer': manufacturer_counts.index, 'Count': manufacturer_counts.values})


alt.Chart(df_manufacturer_counts).mark_bar().encode(
    x='Count:Q',
    y=alt.Y('Manufacturer:N', sort='-x')  # Sort bars by count in descending order
).properties(
    title='Top 5 Car Manufacturers'
)
# Out:
# alt.Chart(...)

# %%
topcars = cars['Manufacturer'].value_counts().head(10)
topcars
toppricemean=[cars[cars['Manufacturer']==i]['Price'].mean() for i in list (topcars.index)]
print(toppricemean)
# Out:
# [22306.00080450523, 14302.447864669994, 18590.331375428294, 15411.85018382353, 14894.873925501433, 20609.468146718147, 14162.073958333332, 20052.594390507013, 9835.84031007752, 11471.77408056042]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
plt.bar(topcars.index, toppricemean, color='blue')
plt.title('Top Cars by Average Price', loc='center', fontweight='bold', fontsize=18)
plt.ylabel('Average Price')
plt.xlabel('Manufacturer')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
for i in cars[[ 'Levy', 'Manufacturer', 'Model', 'Prod. year',
       'Category', 'Leather interior', 'Fuel type', 'Mileage',
       'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
       'Airbags']]:
       plt.figure(figsize=(15, 10))
       top=cars[i].value_counts()[:10]
       color= ['red','green','yellow','blue']
       top.plot(kind='bar',color=color)
       plt.title(str(i) + ' Top Ten')
       plt.show()
# Out:
# <ipython-input-30-fe643497f444>:6: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   top=cars[i].value_counts()[:10]

# %%
from datetime import datetime
import pytz

def get_peru_datetime():
  """
  Returns the current date and time in Peru's time zone.
  """
  peru_timezone = pytz.timezone('America/Lima')
  peru_datetime = datetime.now(peru_timezone)
  return peru_datetime

# Example usage
current_datetime_peru = get_peru_datetime()
current_datetime_peru
# Out:
# datetime.datetime(2025, 2, 27, 20, 19, 27, 56256, tzinfo=<DstTzInfo 'America/Lima' -05-1 day, 19:00:00 STD>)

# %%
# Transformación
from datetime import datetime
dtime = datetime.now()
print(dtime)
cars['Age'] = dtime.year - cars['Prod. year']
cars.head()
# Out:
# 2025-02-28 01:20:07.020280
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km       6.00
# 1               No    Petrol             3  192000 km       6.00
# 2               No    Petrol           1.3  200000 km       4.00
# 3              Yes    Hybrid           2.5  168966 km       4.00
# 4              Yes    Petrol           1.3   91901 km       4.00
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags  Age
# ...

# %%
cars['Mileage']
# Out:
# 0        186005 km
# 1        192000 km
# 2        200000 km
# 3        168966 km
# 4         91901 km
#            ...
# 19232    300000 km
# 19233    161600 km
# 19234    116365 km
# 19235     51258 km
# 19236    186923 km
# Name: Mileage, Length: 18924, dtype: object

# %%
cars['Mileage'] = cars['Mileage'].str.replace('km',"").astype('Int64')
cars.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume  Mileage  Cylinders Gear box type  \
# 0              Yes    Hybrid           3.5   186005       6.00     Automatic
# 1               No    Petrol             3   192000       6.00     Tiptronic
# 2               No    Petrol           1.3   200000       4.00      Variator
# 3              Yes    Hybrid           2.5   168966       4.00     Automatic
# 4              Yes    Petrol           1.3    91901       4.00     Automatic
#
#   Drive wheels   Doors             Wheel   Color  Airbags  Age
# ...

# %%
cars['Levy'] = cars['Levy'].str.replace('-',"0").astype(int)
cars.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     0        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume  Mileage  Cylinders Gear box type  \
# 0              Yes    Hybrid           3.5   186005       6.00     Automatic
# 1               No    Petrol             3   192000       6.00     Tiptronic
# 2               No    Petrol           1.3   200000       4.00      Variator
# 3              Yes    Hybrid           2.5   168966       4.00     Automatic
# 4              Yes    Petrol           1.3    91901       4.00     Automatic
#
#   Drive wheels   Doors             Wheel   Color  Airbags  Age
# ...

# %%
cars['Engine volume'].unique()
# Out:
# array(['3.5', '3', '1.3', '2.5', '2', '1.8', '2.4', '4', '1.6', '3.3',
#        '2.0 Turbo', '2.2 Turbo', '4.7', '1.5', '4.4', '3.0 Turbo',
#        '1.4 Turbo', '3.6', '2.3', '1.5 Turbo', '1.6 Turbo', '2.2',
#        '2.3 Turbo', '1.4', '5.5', '2.8 Turbo', '3.2', '3.8', '4.6', '1.2',
#        '5', '1.7', '2.9', '0.5', '1.8 Turbo', '2.4 Turbo', '3.5 Turbo',
#        '1.9', '2.7', '4.8', '5.3', '0.4', '2.8', '3.2 Turbo', '1.1',
#        '2.1', '0.7', '5.4', '1.3 Turbo', '3.7', '1', '2.5 Turbo', '2.6',
#        '1.9 Turbo', '4.4 Turbo', '4.7 Turbo', '0.8', '0.2 Turbo', '5.7',
#        '4.8 Turbo', '4.6 Turbo', '6.7', '6.2', '1.2 Turbo', '3.4',
#        '1.7 Turbo', '6.3 Turbo', '2.7 Turbo', '4.3', '4.2', '2.9 Turbo',
#        '0', '4.0 Turbo', '20', '3.6 Turbo', '0.3', '3.7 Turbo', '5.9',
#        '5.5 Turbo', '0.2', '2.1 Turbo', '5.6', '6', '0.7 Turbo',
#        '0.6 Turbo', '6.8', '4.5', '0.6', '7.3', '0.1', '1.0 Turbo', '6.3',
# ...

# %%
cars['Engine volume'] = cars['Engine volume'].str.replace('Turbo','').astype(float)

cars.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     0        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type  Engine volume  Mileage  Cylinders Gear box type  \
# 0              Yes    Hybrid           3.50   186005       6.00     Automatic
# 1               No    Petrol           3.00   192000       6.00     Tiptronic
# 2               No    Petrol           1.30   200000       4.00      Variator
# 3              Yes    Hybrid           2.50   168966       4.00     Automatic
# 4              Yes    Petrol           1.30    91901       4.00     Automatic
#
#   Drive wheels   Doors             Wheel   Color  Airbags  Age
# ...

# %%
cars.drop('ID', axis = 1).describe()
# Out:
#               Price      Levy  Prod. year  Engine volume          Mileage  \
# count     18,924.00 18,924.00   18,924.00      18,924.00        18,924.00
# mean      18,587.44    632.89    2,010.91           2.31     1,555,372.72
# std      192,135.63    568.27        5.67           0.88    48,802,205.32
# min            1.00      0.00    1,939.00           0.00             0.00
# 25%        5,331.00      0.00    2,009.00           1.80        70,195.75
# 50%       13,172.00    642.00    2,012.00           2.00       126,400.00
# 75%       22,063.00    917.00    2,015.00           2.50       189,119.75
# max   26,307,500.00 11,714.00    2,020.00          20.00 2,147,483,647.00
#
#        Cylinders   Airbags       Age
# count  18,924.00 18,924.00 18,924.00
# mean        4.58      6.57     14.09
# std         1.20      4.32      5.67
# min         1.00      0.00      5.00
# 25%         4.00      4.00     10.00
# 50%         4.00      6.00     13.00
# ...

# %%
for col in cars.drop('ID',axis=1).describe().columns:
    Q1 = cars[col].quantile(0.25)
    Q3 = cars[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = ((cars[col] < lower_bound) | (cars[col] > upper_bound)).sum()

    total_points = cars[col].shape[0]

    print(f"Total Outliers in {col}: {outliers} -- {round(100 * (outliers / total_points), 2)}%")
# Out:
# Total Outliers in Price: 1055 -- 5.57%
# Total Outliers in Levy: 160 -- 0.85%
# Total Outliers in Prod. year: 962 -- 5.08%
# Total Outliers in Engine volume: 1358 -- 7.18%
# Total Outliers in Mileage: 635 -- 3.36%
# Total Outliers in Cylinders: 4765 -- 25.18%
# Total Outliers in Airbags: 0 -- 0.0%
# Total Outliers in Age: 962 -- 5.08%

# %%
# prompt: eliminar outliers de cars

# Removing outliers
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

for col in cars.drop('ID',axis=1).describe().columns:
  cars = remove_outliers_iqr(cars, col)
cars.head()
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 2  45774419   8467     0        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
#
#   Leather interior Fuel type  Engine volume  Mileage  Cylinders Gear box type  \
# 2               No    Petrol           1.30   200000       4.00      Variator
# 3              Yes    Hybrid           2.50   168966       4.00     Automatic
# 4              Yes    Petrol           1.30    91901       4.00     Automatic
# 5              Yes    Diesel           2.00   160931       4.00     Automatic
# 6              Yes    Hybrid           1.80   258909       4.00     Automatic
#
#   Drive wheels   Doors             Wheel   Color  Airbags  Age
# ...

# %%
cars.drop('ID', axis = 1).describe()
# Out:
#           Price      Levy  Prod. year  Engine volume    Mileage  Cylinders  \
# count 11,744.00 11,744.00   11,744.00      11,744.00  11,744.00  11,744.00
# mean  15,497.99    595.91    2,012.43           1.94 121,429.74       4.00
# std   11,366.75    381.26        3.45           0.39  71,239.91       0.00
# min        1.00      0.00    2,003.00           0.80       0.00       4.00
# 25%    7,035.00    382.00    2,011.00           1.60  69,000.00       4.00
# 50%   14,426.00    642.00    2,013.00           2.00 115,974.00       4.00
# 75%   21,395.00    831.00    2,015.00           2.20 164,000.00       4.00
# max   47,120.00  2,209.00    2,020.00           3.50 346,470.00       4.00
#
#         Airbags       Age
# count 11,744.00 11,744.00
# mean       6.41     12.57
# std        4.09      3.45
# min        0.00      5.00
# 25%        4.00     10.00
# 50%        4.00     12.00
# 75%       12.00     14.00
# max       16.00     22.00

# %%
cars.shape
# Out:
# (11744, 19)

# %%
obj=cars.select_dtypes(include='object')
non_obj=cars.select_dtypes(exclude='object')

# %%
obj.head()
# Out:
#   Manufacturer     Model   Category Leather interior Fuel type Gear box type  \
# 2        HONDA       FIT  Hatchback               No    Petrol      Variator
# 3         FORD    Escape       Jeep              Yes    Hybrid     Automatic
# 4        HONDA       FIT  Hatchback              Yes    Petrol     Automatic
# 5      HYUNDAI  Santa FE       Jeep              Yes    Diesel     Automatic
# 6       TOYOTA     Prius  Hatchback              Yes    Hybrid     Automatic
#
#   Drive wheels   Doors             Wheel   Color
# 2        Front  04-May  Right-hand drive   Black
# 3          4x4  04-May        Left wheel   White
# 4        Front  04-May        Left wheel  Silver
# 5        Front  04-May        Left wheel   White
# 6        Front  04-May        Left wheel   White

# %%
non_obj.head()
# Out:
#          ID  Price  Levy  Prod. year  Engine volume  Mileage  Cylinders  \
# 2  45774419   8467     0        2006           1.30   200000       4.00
# 3  45769185   3607   862        2011           2.50   168966       4.00
# 4  45809263  11726   446        2014           1.30    91901       4.00
# 5  45802912  39493   891        2016           2.00   160931       4.00
# 6  45656768   1803   761        2010           1.80   258909       4.00
#
#    Airbags  Age
# 2        2   19
# 3        0   14
# 4        4   11
# 5        4    9
# 6       12   15

# %%
from sklearn.preprocessing import LabelEncoder
la = LabelEncoder()
for i in range(0,obj.shape[1]):
    obj.iloc[:,i]=la.fit_transform(obj.iloc[:,i])

# %%
obj.head()
# Out:
#   Manufacturer Model Category Leather interior Fuel type Gear box type  \
# 2           16   346        3                0         4             3
# 3           12   333        4                1         2             0
# 4           16   346        3                1         4             0
# 5           17   681        4                1         1             0
# 6           43   614        3                1         2             0
#
#   Drive wheels Doors Wheel Color
# 2            1     1     1     1
# 3            0     1     0    14
# 4            1     1     0    12
# 5            1     1     0    14
# 6            1     1     0    14

# %%
cars_2=pd.concat([non_obj,obj],axis=1)
cars_2.head()
# Out:
#          ID  Price  Levy  Prod. year  Engine volume  Mileage  Cylinders  \
# 2  45774419   8467     0        2006           1.30   200000       4.00
# 3  45769185   3607   862        2011           2.50   168966       4.00
# 4  45809263  11726   446        2014           1.30    91901       4.00
# 5  45802912  39493   891        2016           2.00   160931       4.00
# 6  45656768   1803   761        2010           1.80   258909       4.00
#
#    Airbags  Age Manufacturer Model Category Leather interior Fuel type  \
# 2        2   19           16   346        3                0         4
# 3        0   14           12   333        4                1         2
# 4        4   11           16   346        3                1         4
# 5        4    9           17   681        4                1         1
# 6       12   15           43   614        3                1         2
#
#   Gear box type Drive wheels Doors Wheel Color
# 2             3            1     1     1     1
# ...

# %%
# Modelado
X=cars_2.drop(['Price','ID','Prod. year'],axis=1)
y=cars_2['Price']

# %%
X
# Out:
#        Levy  Engine volume  Mileage  Cylinders  Airbags  Age Manufacturer  \
# 2         0           1.30   200000       4.00        2   19           16
# 3       862           2.50   168966       4.00        0   14           12
# 4       446           1.30    91901       4.00        4   11           16
# 5       891           2.00   160931       4.00        4    9           17
# 6       761           1.80   258909       4.00       12   15           43
# ...     ...            ...      ...        ...      ...  ...          ...
# 19230   645           1.80   307325       4.00       12   14           43
# 19233   831           2.40   161600       4.00        8   14           17
# 19234   836           2.00   116365       4.00        4   15           17
# 19235  1288           2.00    51258       4.00        4   18            6
# 19236   753           2.40   186923       4.00       12   13           17
#
#       Model Category Leather interior Fuel type Gear box type Drive wheels  \
# ...

# %%
y
# Out:
# 2         8467
# 3         3607
# 4        11726
# 5        39493
# 6         1803
#          ...
# 19230      470
# 19233    15681
# 19234    26108
# 19235     5331
# 19236      470
# Name: Price, Length: 11744, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error


from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestRegressor # ensemble model
from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
# Inicialización de los modelos
Model_LR=LinearRegression()
Model_RF=RandomForestRegressor(n_estimators=100, max_features= 7)
Model_SVC=SVR()
Model_GBoosting=GradientBoostingRegressor(learning_rate =.07, max_depth =7, verbose=0)
Model_DT=DecisionTreeRegressor()

# %%
Algo=['LinearRegression','RandomForestRegressor','SVR','GradientBoostingRegressor','DecisionTreeRegressor']
R2=[]
RMSE=[]

# %%
import numpy as np
def predict(model):
    model.fit(x_train,y_train) # entrenamiento
    y_pred = model.predict(x_test) # predicción
    r2=r2_score(y_test,y_pred) # indicador de ajuste
    rmse=np.sqrt(mean_squared_error(y_test,y_pred)) # indicador de ajuste
    R2.append(r2) # indicador de ajuste
    RMSE.append(rmse) # indicador de ajuste
    score=model.score(x_test,y_test) # indicador de ajuste
    print(f'score of model is : {score}')
    print(f'r2 score of model is : {r2}')
    print(f'RMSE of model is : {rmse}')
    print('-------------------------------------------')

# %%
predict(Model_LR)
predict(Model_RF)
predict(Model_SVC)
predict(Model_GBoosting)
predict(Model_DT)
# Out:
# score of model is : 0.24553818632155955
# r2 score of model is : 0.24553818632155955
# RMSE of model is : 9894.18290455255
# -------------------------------------------
# score of model is : 0.7983488394274654
# r2 score of model is : 0.7983488394274654
# RMSE of model is : 5115.188773754965
# -------------------------------------------
# score of model is : 0.00212647505029695
# r2 score of model is : 0.00212647505029695
# RMSE of model is : 11378.867831492931
# -------------------------------------------
# score of model is : 0.7773392495651519
# r2 score of model is : 0.7773392495651519
# RMSE of model is : 5375.057779346557
# -------------------------------------------
# score of model is : 0.6105622125102526
# r2 score of model is : 0.6105622125102526
# RMSE of model is : 7108.538950870663
# -------------------------------------------

# %%
pd.DataFrame({'Algorithm':Algo,'R2_score':R2,'RMSE':RMSE})
# Out:
#                    Algorithm  R2_score      RMSE
# 0           LinearRegression      0.25  9,894.18
# 1      RandomForestRegressor      0.80  5,115.19
# 2                        SVR      0.00 11,378.87
# 3  GradientBoostingRegressor      0.78  5,375.06
# 4      DecisionTreeRegressor      0.61  7,108.54

# %%
# prompt: genera un nuevo registro para su predicción y predice con el modelo random forest

import pandas as pd
# Crea un nuevo registro para la predicción
new_data = pd.DataFrame({
    'Levy': [800],
    'Mileage': [150000],
    'Engine volume': [2.0],
    'Cylinders': [4],
    'Age': [4],
    'Manufacturer': [10],  # Reemplaza con el valor correspondiente para el fabricante
    'Model': [50],  # Reemplaza con el valor correspondiente para el modelo
    'Category': [1],  # Reemplaza con el valor correspondiente para la categoría
    'Leather interior': [1],  # Reemplaza con el valor correspondiente para el interior de cuero
    'Fuel type': [1],  # Reemplaza con el valor correspondiente para el tipo de combustible
    'Gear box type': [1],  # Reemplaza con el valor correspondiente para el tipo de caja de cambios
    'Drive wheels': [1],  # Reemplaza con el valor correspondiente para las ruedas motrices
    'Doors': [4],  # Reemplaza con el valor correspondiente para las puertas
    'Wheel': [0],  # Reemplaza con el valor correspondiente para las ruedas
    'Color': [1],  # Reemplaza con el valor correspondiente para el color
    'Airbags': [6]  # Reemplaza con el valor correspondiente para las bolsas de aire
})

# Predice con el modelo Random Forest
prediction = Model_RF.predict(new_data.values)
print(f'La predicción del precio es: {prediction[0]}')
# Out:
# La predicción del precio es: 25306.98

# %%
# prompt: dame 3 datos dummy con los que pueda realizar una predicción con el modelo Model_RF

import pandas as pd
# Crea tres nuevos registros para la predicción
new_data = pd.DataFrame({
    'Levy': [800, 1000, 500],
    'Mileage': [150000, 80000, 200000],
    'Engine volume': [2.0, 2.5, 1.8],
    'Cylinders': [4, 4, 4],
    'Age': [4, 2, 7],
    'Manufacturer': [10, 20, 5],  # Reemplaza con valores válidos de fabricante
    'Model': [50, 100, 25],       # Reemplaza con valores válidos de modelo
    'Category': [1, 0, 2],       # Reemplaza con valores válidos de categoría
    'Leather interior': [1, 0, 1], # Reemplaza con valores válidos para interior de cuero
    'Fuel type': [1, 2, 0],       # Reemplaza con valores válidos de tipo de combustible
    'Gear box type': [1, 0, 1],    # Reemplaza con valores válidos para el tipo de caja de cambios
    'Drive wheels': [1, 0, 2],    # Reemplaza con valores válidos para las ruedas motrices
    'Doors': [4, 4, 5],            # Reemplaza con valores válidos para las puertas
    'Wheel': [0, 1, 0],          # Reemplaza con valores válidos para las ruedas
    'Color': [1, 5, 2],          # Reemplaza con valores válidos para el color
    'Airbags': [6, 8, 4]          # Reemplaza con valores válidos para las bolsas de aire
})

# Predice con el modelo Random Forest
predictions = Model_RF.predict(new_data.values)
print(f'Las predicciones de precios son: {predictions}')
# Out:
# Las predicciones de precios son: [25306.98       12632.628      25244.92333333]

# %%
# !pip install genaibook
from genaibook.core import get_device
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 25.0 MB/s eta 0:00:00
# ...

# %%
device = get_device()
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    "stable-diffusion-v1-5/stable-diffusion-v1-5",
    torch_dtype=torch.float16,
    variant="fp16")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.fp16.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# model.fp16.safetensors:   0%|          | 0.00/608M [00:00<?, ?B/s]
# text_encoder%2Fconfig.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# tokenizer%2Fmerges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# ...

# %%
pipe = pipe.to(device)

# %%
promt = 'an expert in machine learning working in an insurance company'
pipe(promt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
