# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import quantecon as qe

# %%
from statsmodels.tsa.arima_process import ArmaProcess
import statsmodels.api as sm

# %%
from IPython.display import display, Math, Latex

# %%
display(Math('$Y_t$ = 0.5$Y_{t-1}$ + $\epsilon_t'))
# Out:
# $\displaystyle Y_t$ = 0.5$Y_{t-1}$ + $\epsilon_t$

# %%
plt.figure(figsize=(10,8))
ar1=np.array([1, -0.5])
AR_object1 = ArmaProcess(ar1)
simulated_data_1 = AR_object1.generate_sample(nsample=1000)
plt.plot(simulated_data_1);

# %% [markdown]
# # FAS & FAP

# %%
a = sm.tsa.stattools.acf(simulated_data_1)
# Out:
# /home/alvin/.local/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:568: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))

# ACF chart
fig = sm.graphics.tsa.plot_acf(a, ax=ax1)
# PACF chart
fig = sm.graphics.tsa.plot_pacf(a, ax=ax2)
# ignorar el primero

# %% [markdown]
# # Example 2

# %%
display(Math('$X_t$ = 0.1 + 0.3$X_{t-1}$ + 0.25$X_{t-2}$ + $\epsilon_t'))
# Out:
# $\displaystyle X_t$ = 0.1 + 0.3$X_{t-1}$ + 0.25$X_{t-2}$ + $\epsilon_t$

# %%
plt.figure(figsize=(10,8))
ar2=np.array([1,-0.3,-0.25])
AR_object2 = ArmaProcess(ar2)
simulated_data_2 = AR_object2.generate_sample(nsample=1000)
plt.plot(simulated_data_2);

# %% [markdown]
# # FAS & FAP

# %%
b = sm.tsa.stattools.acf(simulated_data_2)
b1= sm.tsa.stattools.pacf(simulated_data_2)
b.shape
# te da los números de la prueba
# Out:
# /home/alvin/.local/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:568: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# (41,)

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))

# ACF chart
fig = sm.graphics.tsa.plot_acf(b, ax=ax1)
# PACF chart
fig = sm.graphics.tsa.plot_pacf(b, ax=ax2)
# ignorar el primero

# %%
simulated_data_1.shape
# Out:
# (1000,)
